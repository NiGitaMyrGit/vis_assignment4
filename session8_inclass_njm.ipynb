# %% [markdown]
# # Introducing CNNS with TensorFlow
#
#
# In this notebook, we're going to see how we can use ```TensorFlow``` to build convolutional neural networks to work with colour image data.

# %% [markdown]
# ## Load libraries

# %%
# data tools
import os
import numpy as np
import matplotlib.pyplot as plt

# sklearn tools
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report

# tf tools
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, 
                                     MaxPooling2D, 
                                     Activation, 
                                     Flatten, 
                                     Dense)
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K
# Out:
# 2023-03-31 13:24:34.560955: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# __Define plotting function__

# %%
def plot_history(H, epochs):
    plt.style.use("seaborn-colorblind")

    plt.figure(figsize=(12,6))
    plt.subplot(1,2,1)
    plt.plot(np.arange(0, epochs), H.history["loss"], label="train_loss")
    plt.plot(np.arange(0, epochs), H.history["val_loss"], label="val_loss", linestyle=":")
    plt.title("Loss curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.tight_layout()
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(np.arange(0, epochs), H.history["accuracy"], label="train_acc")
    plt.plot(np.arange(0, epochs), H.history["val_accuracy"], label="val_acc", linestyle=":")
    plt.title("Accuracy curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.tight_layout()
    plt.legend()
    plt.show()

# %% [markdown]
# __Load cifar10 data__

# %% [markdown]
# We first want to load the ```cifar-10``` dataset, normalize the values, and then binarize the labels.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 7s 0us/step

# %% [markdown]
# **Question:** As an experiment, see what happens if you try to train the model with un-scaled images. Does it affect performance?

# %%
X_train = X_train/255
X_test = X_test/255

# %%
# create one-hot encodings
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)

# %% [markdown]
# We'll also manually create a list of labels for when we come to print the classification report later.

# %%
# initialize label names for CIFAR-10 dataset
label_names = ["airplane", "automobile", 
              "bird", "cat", 
              "deer", "dog", 
              "frog", "horse", 
              "ship", "truck"]

# %% [markdown]
# ## ShallowNet

# %% [markdown]
# We're going to begin by creating one of the simplest CNN architectures with only a single convolutional layer. This type of architecture is known as the ShallowNet architecture:
# >INPUT => CONV => ReLU => FC

# %%
#initalise model
model = Sequential()

# define CONV => ReLU
model.add(Conv2D(32, 
                (3,3),
                padding = "same",
                input_shape = (32,2,2)))
model.add(Activation("relu"))
          
# FC classifier
model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu"))
model.add(Dense(10))
model.add(Activation("softmax"))

# %% [markdown]
# __Compile model__

# %% [markdown]
# We then compile our model using some of the same arguments we've already seen in different contexts.

# %%
sgd = SGD(learning_rate =.001)
model.compile(loss="categorical_crossentropy",
              optimizer=sgd,
              metrics=["accuracy"])

# %% [markdown]
# __Model summary__

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 128)               4194432
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
#  activation_2 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 4,196,618
# Trainable params: 4,196,618
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# __Plot model__

# %%
plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# __Train model__

# %% [markdown]
# running this on 16CPU machine takes around 8 minutes
# Finally, we train the model on the data and get our predictions.

# %%
H = model.fit(X_train, 
              y_train,
              validation_split=0.1,
              batch_size=32,
              epochs=20,
              verbose=1)
# Out:
# Epoch 1/20
# 704/704 [==============================] - 26s 37ms/step - loss: 1.2999 - accuracy: 0.5418 - val_loss: 1.3448 - val_accuracy: 0.5172
# Epoch 2/20
# 704/704 [==============================] - 26s 37ms/step - loss: 1.2919 - accuracy: 0.5446 - val_loss: 1.3756 - val_accuracy: 0.5132
# Epoch 3/20
# 704/704 [==============================] - 27s 38ms/step - loss: 1.2842 - accuracy: 0.5463 - val_loss: 1.3394 - val_accuracy: 0.5246
# Epoch 4/20
# 704/704 [==============================] - 27s 38ms/step - loss: 1.2756 - accuracy: 0.5512 - val_loss: 1.3756 - val_accuracy: 0.5126
# Epoch 5/20
# 704/704 [==============================] - 27s 38ms/step - loss: 1.2686 - accuracy: 0.5534 - val_loss: 1.3049 - val_accuracy: 0.5396
# Epoch 6/20
# 704/704 [==============================] - 27s 38ms/step - loss: 1.2604 - accuracy: 0.5566 - val_loss: 1.3945 - val_accuracy: 0.4956
# Epoch 7/20
# 704/704 [==============================] - 26s 38ms/step - loss: 1.2528 - accuracy: 0.5585 - val_loss: 1.3075 - val_accuracy: 0.5318
# Epoch 8/20
# 704/704 [==============================] - 26s 38ms/step - loss: 1.2441 - accuracy: 0.5616 - val_loss: 1.2767 - val_accuracy: 0.5506
# Epoch 9/20
# 704/704 [==============================] - 26s 38ms/step - loss: 1.2357 - accuracy: 0.5657 - val_loss: 1.3323 - val_accuracy: 0.5258
# Epoch 10/20
# 704/704 [==============================] - 26s 37ms/step - loss: 1.2295 - accuracy: 0.5686 - val_loss: 1.3052 - val_accuracy: 0.5434
# Epoch 11/20
# 704/704 [==============================] - 27s 38ms/step - loss: 1.2209 - accuracy: 0.5720 - val_loss: 1.3314 - val_accuracy: 0.5338
# Epoch 12/20
# 704/704 [==============================] - 26s 37ms/step - loss: 1.2153 - accuracy: 0.5726 - val_loss: 1.7166 - val_accuracy: 0.4174
# Epoch 13/20
# 704/704 [==============================] - 26s 37ms/step - loss: 1.2078 - accuracy: 0.5764 - val_loss: 1.2592 - val_accuracy: 0.5556
# Epoch 14/20
# 704/704 [==============================] - 26s 37ms/step - loss: 1.2004 - accuracy: 0.5780 - val_loss: 1.2835 - val_accuracy: 0.5432
# Epoch 15/20
# 704/704 [==============================] - 27s 38ms/step - loss: 1.1927 - accuracy: 0.5826 - val_loss: 1.3722 - val_accuracy: 0.5120
# Epoch 16/20
# 704/704 [==============================] - 27s 38ms/step - loss: 1.1852 - accuracy: 0.5846 - val_loss: 1.3838 - val_accuracy: 0.5074
# Epoch 17/20
# 704/704 [==============================] - 26s 38ms/step - loss: 1.1786 - accuracy: 0.5875 - val_loss: 1.2599 - val_accuracy: 0.5578
# Epoch 18/20
# 704/704 [==============================] - 26s 38ms/step - loss: 1.1716 - accuracy: 0.5881 - val_loss: 1.4648 - val_accuracy: 0.4728
# Epoch 19/20
# 704/704 [==============================] - 27s 38ms/step - loss: 1.1659 - accuracy: 0.5951 - val_loss: 1.2601 - val_accuracy: 0.5474
# Epoch 20/20
# 704/704 [==============================] - 26s 38ms/step - loss: 1.1598 - accuracy: 0.5935 - val_loss: 1.2676 - val_accuracy: 0.5518

# %% [markdown]
# __Evaluate model__

# %%
predictions = model.predict(X_test, batch_size=32)
# Out:
# 157/157 [==============================] - 1s 9ms/step

# %%
print(classification_report(y_test.argmax(axis=1),
                            predictions.argmax(axis=1),
                            target_names=label_names))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.42      0.83      0.56      1000
#   automobile       0.77      0.50      0.61      1000
#         bird       0.48      0.44      0.46      1000
#          cat       0.43      0.42      0.42      1000
#         deer       0.54      0.42      0.47      1000
#          dog       0.53      0.42      0.47      1000
#         frog       0.72      0.58      0.64      1000
#        horse       0.66      0.60      0.63      1000
#         ship       0.76      0.50      0.60      1000
#        truck       0.49      0.75      0.59      1000
#
#     accuracy                           0.55     10000
#    macro avg       0.58      0.55      0.55     10000
# weighted avg       0.58      0.55      0.55     10000

# %% [markdown]
# We can also use the ```plot_history()``` function available from ```TensorFlow``` to see how our model performs during training.
#
# These plots can tell us *a lot* about whether a model is under- or over-fiting the data. You read more at [this fantastic blog post](https://machinelearningmastery.com/learning-curves-for-diagnosing-machine-learning-model-performance/).
#
# Other useful blogs are [here](https://rstudio-conf-2020.github.io/dl-keras-tf/notebooks/learning-curve-diagnostics.nb.html) and there's a good video overview [here](https://youtu.be/p3CcfIjycBA).
#
# The two results track each othe rquite smoothly, performancence should be increasing, and loss should be decreasing

# %%
plot_history(H, 20)
# Out:
# /tmp/ipykernel_2019/3716877966.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-colorblind")

# %% [markdown]
# ## LeNet

# %% [markdown]
# Next, we'll look at a slightly more complicated CNN architecture, known as ```LeNet``` after its creator Yann LeCun, who is now Chief AI Scientist at Meta. You can read more [here](https://en.wikipedia.org/wiki/LeNet).
# >INPUT => CONV => ReLU => MAXPOOL => CONV => ReLU => MAXPOOL => FC => ReLU => FC

# %% [markdown]
# __Define model__

# %%
# define model
model = Sequential()

# first set of layers CONV => RELU => MAXPOOL
model.add(Conv2D(32, (3,3),
                 padding="same",
                 input_shape=(32,32,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size = (2,2),
                       strides = (2,2)))

# second set of layers CONV => RELU => MAXPOOL
model.add(Conv2D(50, (5,5),
                 padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size = (2,2),
                       strides = (2,2)))

# FC => RELU
model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu"))

# softmax classifier
model.add(Dense(10))
model.add(Activation("softmax"))

# %% [markdown]
# __Compile model__

# %%
sgd = SGD(learning_rate=0.001)
model.compile(loss="categorical_crossentropy",
              optimizer=sgd,
              metrics=["accuracy"])

# %% [markdown]
# __Model summary__

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        896
#
#  activation_3 (Activation)   (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 50)        40050
#
#  activation_4 (Activation)   (None, 16, 16, 50)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 50)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 3200)              0
#
#  dense_2 (Dense)             (None, 128)               409728
#
#  activation_5 (Activation)   (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
#  activation_6 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 451,964
# Trainable params: 451,964
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# __Train model__

# %%
# train model
H = model.fit(X_train, 
              y_train, 
              validation_split=0.1, 
              batch_size=32,
              epochs=20,
              verbose=1)
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 30s 21ms/step - loss: 2.2589 - accuracy: 0.1818 - val_loss: 2.1989 - val_accuracy: 0.2502
# Epoch 2/20
# 1407/1407 [==============================] - 29s 21ms/step - loss: 2.1003 - accuracy: 0.2684 - val_loss: 2.0068 - val_accuracy: 0.2954
# Epoch 3/20
# 1407/1407 [==============================] - 29s 21ms/step - loss: 1.9520 - accuracy: 0.3098 - val_loss: 1.9292 - val_accuracy: 0.3186
# Epoch 4/20
# 1407/1407 [==============================] - 29s 20ms/step - loss: 1.8798 - accuracy: 0.3413 - val_loss: 1.8660 - val_accuracy: 0.3360
# Epoch 5/20
# 1407/1407 [==============================] - 29s 21ms/step - loss: 1.8179 - accuracy: 0.3647 - val_loss: 1.7893 - val_accuracy: 0.3640
# Epoch 6/20
# 1407/1407 [==============================] - 29s 21ms/step - loss: 1.7593 - accuracy: 0.3872 - val_loss: 1.7500 - val_accuracy: 0.3656
# Epoch 7/20
# 1407/1407 [==============================] - 29s 21ms/step - loss: 1.7031 - accuracy: 0.4040 - val_loss: 1.7054 - val_accuracy: 0.3914
# Epoch 8/20
# 1407/1407 [==============================] - 29s 21ms/step - loss: 1.6502 - accuracy: 0.4196 - val_loss: 1.6522 - val_accuracy: 0.4114
# Epoch 9/20
# 1407/1407 [==============================] - 29s 21ms/step - loss: 1.6011 - accuracy: 0.4368 - val_loss: 1.6589 - val_accuracy: 0.3980
# Epoch 10/20
# 1407/1407 [==============================] - 29s 21ms/step - loss: 1.5582 - accuracy: 0.4486 - val_loss: 1.5695 - val_accuracy: 0.4384
# Epoch 11/20
# 1407/1407 [==============================] - 29s 21ms/step - loss: 1.5212 - accuracy: 0.4640 - val_loss: 1.5355 - val_accuracy: 0.4484
# Epoch 12/20
# 1407/1407 [==============================] - 29s 21ms/step - loss: 1.4894 - accuracy: 0.4725 - val_loss: 1.5845 - val_accuracy: 0.4306
# Epoch 13/20
# 1407/1407 [==============================] - 30s 21ms/step - loss: 1.4632 - accuracy: 0.4846 - val_loss: 1.4977 - val_accuracy: 0.4562
# Epoch 14/20
# 1407/1407 [==============================] - 29s 21ms/step - loss: 1.4387 - accuracy: 0.4920 - val_loss: 1.4374 - val_accuracy: 0.4880
# Epoch 15/20
# 1407/1407 [==============================] - 29s 21ms/step - loss: 1.4168 - accuracy: 0.4992 - val_loss: 1.4493 - val_accuracy: 0.4852
# Epoch 16/20
# 1407/1407 [==============================] - 29s 21ms/step - loss: 1.3963 - accuracy: 0.5068 - val_loss: 1.4299 - val_accuracy: 0.4858
# Epoch 17/20
# 1407/1407 [==============================] - 29s 21ms/step - loss: 1.3778 - accuracy: 0.5128 - val_loss: 1.3963 - val_accuracy: 0.5026
# Epoch 18/20
# 1407/1407 [==============================] - 29s 21ms/step - loss: 1.3611 - accuracy: 0.5183 - val_loss: 1.4754 - val_accuracy: 0.4700
# Epoch 19/20
# 1407/1407 [==============================] - 30s 21ms/step - loss: 1.3441 - accuracy: 0.5247 - val_loss: 1.4396 - val_accuracy: 0.5022
# Epoch 20/20
# 1407/1407 [==============================] - 29s 21ms/step - loss: 1.3278 - accuracy: 0.5305 - val_loss: 1.3423 - val_accuracy: 0.5284

# %%
plot_history(H,20)
# Out:
# /tmp/ipykernel_2019/3716877966.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-colorblind")

# %%
predictions = model.predict(X_test, batch_size=32)
print(classification_report(y_test.argmax(axis=1),
                            predictions.argmax(axis=1),
                            target_names=label_names))
# Out:
# 313/313 [==============================] - 2s 6ms/step
#               precision    recall  f1-score   support
#
#     airplane       0.60      0.54      0.57      1000
#   automobile       0.66      0.60      0.63      1000
#         bird       0.39      0.41      0.40      1000
#          cat       0.42      0.21      0.28      1000
#         deer       0.43      0.49      0.46      1000
#          dog       0.51      0.37      0.43      1000
#         frog       0.49      0.72      0.58      1000
#        horse       0.51      0.65      0.57      1000
#         ship       0.60      0.68      0.64      1000
#        truck       0.60      0.50      0.54      1000
#
#     accuracy                           0.52     10000
#    macro avg       0.52      0.52      0.51     10000
# weighted avg       0.52      0.52      0.51     10000
